# %%
print(type(3)) # int
print(type(1.5)) #float
print(type(-1.5)) #float
print(type(True)) #bool
print(type("Hello Word")) #string
print(type(1j)) #complex
# variable
age = 11 # lowwercase
birth_day = 26 # snakecase
myName = 'Nguyễn Khả Qúy' # khai báo biến kiểu lạc đà
print(_) # dùng để in giá trị ra màn hình máy tính
# input -> str
""
''
sentence1 = "I\"m Qúy"
sentence2 = "I'm Qúy"
print(sentence1)
print(sentence2)
num = int(input("Nhập vào một số bất kì: "))
print(num)
print(type(num))
# casting int
print(int("12"))
print(int(1.8))
print(int(2.8))
# casting float
print(float(1))
print(float(2.8))
print(float("3"))
print(float("4.2"))
# casting str
print(str("s1"))
print(str(2))
print(str(3.0))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'complex'>
#
# I"m Qúy
# I'm Qúy
# Nhập vào một số bất kì:  2
# 2
# <class 'int'>
# 12
# 1
# 2
# 1.0
# 2.8
# 3.0
# 4.2
# s1
# 2
# 3.0
